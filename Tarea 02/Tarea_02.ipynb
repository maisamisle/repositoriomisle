# %% [markdown]
# # Problema 1. Clasificador de temperatura

# %%
for n in range(-30, 50):
  if n < 0:
   print(n, "Muy frio")
  if 0 <= n <= 24:
   print(n, "Templado")
  if n >= 25:
   print(n, "Caluroso")
# Out:
# -30 Muy frio
# -29 Muy frio
# -28 Muy frio
# -27 Muy frio
# -26 Muy frio
# -25 Muy frio
# -24 Muy frio
# -23 Muy frio
# -22 Muy frio
# -21 Muy frio
# -20 Muy frio
# -19 Muy frio
# -18 Muy frio
# -17 Muy frio
# -16 Muy frio
# -15 Muy frio
# -14 Muy frio
# -13 Muy frio
# -12 Muy frio
# -11 Muy frio
# -10 Muy frio
# -9 Muy frio
# -8 Muy frio
# -7 Muy frio
# -6 Muy frio
# -5 Muy frio
# -4 Muy frio
# -3 Muy frio
# -2 Muy frio
# -1 Muy frio
# 0 Templado
# 1 Templado
# 2 Templado
# 3 Templado
# 4 Templado
# 5 Templado
# 6 Templado
# 7 Templado
# 8 Templado
# 9 Templado
# 10 Templado
# 11 Templado
# 12 Templado
# 13 Templado
# 14 Templado
# 15 Templado
# 16 Templado
# 17 Templado
# 18 Templado
# 19 Templado
# 20 Templado
# 21 Templado
# 22 Templado
# 23 Templado
# 24 Templado
# 25 Caluroso
# 26 Caluroso
# 27 Caluroso
# 28 Caluroso
# 29 Caluroso
# 30 Caluroso
# 31 Caluroso
# 32 Caluroso
# 33 Caluroso
# 34 Caluroso
# 35 Caluroso
# 36 Caluroso
# 37 Caluroso
# 38 Caluroso
# 39 Caluroso
# ...

# %% [markdown]
# # Problema 2. Números especiales del robot

# %%
for x in range(1, 101):
  if x % 10 == 0:
    print(f"{x} Bip Bip")
  elif x % 5 == 0:
    print(f"{x} Bip")
# Out:
# 5 Bip
# 10 Bip Bip
# 15 Bip
# 20 Bip Bip
# 25 Bip
# 30 Bip Bip
# 35 Bip
# 40 Bip Bip
# 45 Bip
# 50 Bip Bip
# 55 Bip
# 60 Bip Bip
# 65 Bip
# 70 Bip Bip
# 75 Bip
# 80 Bip Bip
# 85 Bip
# 90 Bip Bip
# 95 Bip
# 100 Bip Bip

# %% [markdown]
# # Problema 3. Detector de puntaje gamer

# %%
x = int(input("Ingresa primer puntaje: "))
y = int(input("Ingresa segundo puntaje: "))
suma = x + y
if suma < 50:
  print("Nivel principiante")
if suma >= 50 and suma < 80:
  print("Nivel intermedio")
if suma >= 80:
  print("Nivel pro")
# Out:
# Ingresa primer puntaje: 50
# Ingresa segundo puntaje: 2
# Nivel intermedio

# %% [markdown]
# # Problema 4. Calculador de perfil musical

# %%
edad = int(input("Ingresa tu edad: "))
le_gusta_musica = input("¿Te gusta la musica? (si/no) ")
le_gusta_bailar = input("¿te gusta bailar? (si/no) ")

if edad >= 18 and le_gusta_musica == "si" and le_gusta_bailar == "si":
  print("Eres una estrella de la fiesta")
elif le_gusta_musica == "si" and le_gusta_bailar == "no":
  print("Te gusta la música, pero no tanto bailar")
else:
  print("Tienes tu propio estilo")
# Out:
# Ingresa tu edad: 99
# ¿Te gusta la musica? (si/no) si
# ¿te gusta bailar? (si/no) si
# Eres una estrella de la fiesta
